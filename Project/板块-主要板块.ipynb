# %% [markdown]
# # 板块估值
#
# - 作者：DGC'Idea
# - 版本：V0.2
# - 更新日期：2018年2月4日
#
# ----------
#
# - 获取中证官网板块估值数据；

# %% [markdown]
# ## 1.准备

# %%
#导入库
import numpy as np
import pandas as pd

import sys
sys.path.append('../PF')
# sys.path.append('../VD')

from pf_plt import Plt

plt=Plt('csv','../Data/')
# Out:
# 数据引擎：运行于研究
# auth success
# 板块框架：运行于研究

# %% [markdown]
# ## 2.获取数据

# %%
plt.data.update(plt.pool.track)
# Out:
# 数据更新：板块，无需更新

# %% [markdown]
# ## 3.数据分析

# %%
plt.value.update(plt.pool.track,[10,5,3,0],True)
plt.change.update(plt.pool.track,['dyr','pe','pb'],force=True)
# Out:
# 数据分析：中小板，[ 股息率 ] 数据dyr
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-96d77e7c2fe4> in <module>
#       1 plt.value.update(plt.pool.track,[10,5,3,0],True)
# ----> 2 plt.change.update(plt.pool.track,['dyr','pe','pb'],force=True)
#
# f:\code\Python\Quant\lmQuant\PF\pf.py in update(self, codes, items, force)
#     468         # 需要更新，或强制更新
#     469         if need_analysis or force:
# --> 470             df=self.get_analysis(codes,items)
#     471             # 保存分析表
#     472             self.save(df)
#
# f:\code\Python\Quant\lmQuant\PF\pf.py in get_analysis(self, codes, items)
#     656                 #获取数据
#     657                 print (item)
# --> 658                 df=self.data.read(code,items=[item])#
#     659                 # df=self.data.read(code)[[item]]
#     660                 #标准分析
#
# ...

# %% [markdown]
# ## 4.估值表格

# %% [markdown]
# ### 4.1.PE

# %%
plt.value.table.pe()
# Out:
#        名称     PE  高度(%)  区间    最低值     最高值    中位值  距底(%)    机会值    危险值
# ZXB   中小板  13.62   0.00  极低  13.62   84.11  35.26   0.00  26.72  45.75
# CYB   创业板  25.71  11.57  较低   9.91  147.06  45.78 -61.45  32.17  64.26
# SZB  深市主板  46.53  99.95  极高   9.48   46.53  19.73 -79.63  16.74  25.58
# SZA  深圳A股  17.18   0.28  极低   9.32   68.35  26.68 -45.75  23.03  37.00
# SHA  上海A股  16.75  91.40  极高   9.27   59.05  13.31 -44.66  10.99  15.92
# HSA  沪深A股  28.41  98.59  极高  11.69   54.22  16.03 -58.85  13.44  20.68

# %% [markdown]
# ### 4.2.PB

# %%
plt.value.table.pb()
# Out:
#        名称    PB  高度(%)  区间   最低值    最高值   中位值  距底(%)   机会值   危险值
# ZXB   中小板  2.87  26.56  偏低  1.40   8.67  3.34 -51.22  2.77  4.38
# CYB   创业板  4.30  55.62  合理  1.38  13.05  4.13 -67.91  2.98  5.89
# SZB  深市主板  1.87  18.99  较低  1.42   5.66  2.27 -24.06  1.88  2.85
# SZA  深圳A股  2.66  37.94  偏低  1.69   6.86  2.90 -36.47  2.46  3.72
# SHA  上海A股  1.46  25.29  偏低  1.24   4.94  1.66 -15.07  1.42  1.89
# HSA  沪深A股  1.79  32.68  偏低  1.43   3.95  2.01 -20.11  1.70  2.30

# %% [markdown]
# ### 4.3.股息率

# %%
plt.value.table.dyr()
# Out:
#        名称   股息率  高度(%)  区间   最低值   最高值   中位值  距底(%)   机会值   危险值
# CYB   创业板  0.70  68.68  偏高  0.14  2.86  0.49 -80.00  0.31  1.01
# SHA  上海A股  2.57  71.91  偏高  0.16  5.95  2.07 -93.77  1.79  2.75
# ZXB   中小板  2.07  94.65  极高  0.29  5.28  1.00 -85.99  0.68  1.66
# HSA  沪深A股  2.74  98.52  极高  0.29  2.91  1.79 -89.42  1.45  2.22
# SZA  深圳A股  3.02  99.10  极高  0.32  5.34  1.06 -89.40  0.73  1.52
# SZB  深市主板  5.93  99.21  极高  0.36  6.32  1.16 -93.93  0.93  2.05

# %% [markdown]
# ## 5.估值图表

# %% [markdown]
# ### 5.1.PE

# %%
plt.value.chart.pe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-d54b6020e382> in <module>
# ----> 1 plt.value.chart.pe()
#
# f:\code\Python\Quant\lmQuant\PF\pf_plt.py in pe(self, years, period, quantile)
#     127     def pe(self,years=10,period='W',quantile=True):
#     128         for code in self.pool.track:
# --> 129             fig=self.line_one(code,'pe','',years,'',period,quantile)
#     130
#     131     def pb(self,years=10,period='W',quantile=True):
#
# f:\code\Python\Quant\lmQuant\PF\pf.py in line_one(self, code, item, mode, years, right, period, quantile)
#    1039             item_list+=[right]
#    1040         #读取数据
# -> 1041         df=self.data.read(code,years=years,items=item_list,period=period)
#    1042         #获取数据分析表数据
#    1043         table=self.analyse.read(years)
#
# ...

# %% [markdown]
# ### 5.2.PB

# %%
plt.value.chart.pb()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f6402fa7b7a1> in <module>
# ----> 1 plt.value.chart.pb()
#
# f:\code\Python\Quant\lmQuant\PF\pf_plt.py in pb(self, years, period, quantile)
#     131     def pb(self,years=10,period='W',quantile=True):
#     132         for code in self.pool.track:
# --> 133             fig=self.line_one(code,'pb','',years,'',period,quantile)
#     134
#     135
#
# f:\code\Python\Quant\lmQuant\PF\pf.py in line_one(self, code, item, mode, years, right, period, quantile)
#    1039             item_list+=[right]
#    1040         #读取数据
# -> 1041         df=self.data.read(code,years=years,items=item_list,period=period)
#    1042         #获取数据分析表数据
#    1043         table=self.analyse.read(years)
#
# f:\code\Python\Quant\lmQuant\PF\pf.py in read(self, code, items, years, start_date, period)
#     209         """
# ...

# %% [markdown]
# ### 5.3.股息率

# %%
plt.value.chart.dyr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-58109f8a08c5> in <module>
# ----> 1 plt.value.chart.dyr()
#
# f:\code\Python\Quant\lmQuant\PF\pf_plt.py in dyr(self, years, period, quantile)
#     136     def dyr(self,years=10,period='W',quantile=True):
#     137         for code in self.pool.track:
# --> 138             fig=self.line_one(code,'dyr','',years,'',period,quantile)
#     139
#     140
#
# f:\code\Python\Quant\lmQuant\PF\pf.py in line_one(self, code, item, mode, years, right, period, quantile)
#    1039             item_list+=[right]
#    1040         #读取数据
# -> 1041         df=self.data.read(code,years=years,items=item_list,period=period)
#    1042         #获取数据分析表数据
#    1043         table=self.analyse.read(years)
#
# f:\code\Python\Quant\lmQuant\PF\pf.py in read(self, code, items, years, start_date, period)
#     209         """
# ...

# %% [markdown]
# ## 6.行情图表

# %% [markdown]
# ### 6.1.PE

# %%
fig=plt.change.chart.heat(plt.pool.track,'pe',title='板块-PE 阶段涨跌')

# %% [markdown]
# ### 6.2.PB

# %%
fig=plt.change.chart.heat(plt.pool.track,'pb',title='板块-PB 阶段涨跌')

# %% [markdown]
# ## 7.标的

# %% [markdown]
# ### 7.1.创建标的

# %%
_codes={
    'SHA':'上海A股',
    'SZA':'深圳A股',
    'HSA':'沪深A股',
    'SZB':'深市主板',
    'ZXB':'中小板',
    'CYB':'创业板',
   }

plt.pool.create(_codes)

# %% [markdown]
# ### 7.2.显示标的

# %%
plt.pool.show()
# Out:
#        名称
# ZXB   中小板
# CYB   创业板
# SZB  深市主板
# SZA  深圳A股
# SHA  上海A股
# HSA  沪深A股
