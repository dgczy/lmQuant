# %% [markdown]
# # 板块估值
#
# - 作者：DGC'Idea
# - 版本：V0.2
# - 更新日期：2018年2月4日
#
# ----------
#
# - 获取中证官网板块估值数据；

# %% [markdown]
# ## 1.准备

# %%
#导入库
import numpy as np
import pandas as pd

import sys
sys.path.append('../PF')
# sys.path.append('../VD')

from pf_plt import Plt

plt=Plt('csv','../Data/')
# Out:
# 数据引擎：准备好
# auth success
# 板块框架：运行于研究

# %% [markdown]
# ## 2.获取数据

# %%
plt.data.update(plt.pool.track)
# Out:
# 数据更新：板块，无需更新

# %% [markdown]
# ## 3.数据分析

# %%
plt.value.update(plt.pool.track,[10,5,3,0],True)
plt.change.update(plt.pool.track,['dyr','pe','pb'],force=True)
# Out:
# 数据分析：中小板，[ 股息率 ] 数据../TL\tl.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pre'] = df.iloc[:, 0].shift(1)
# 数据分析：板块行情，分析完毕

# %% [markdown]
# ## 4.估值表格

# %% [markdown]
# ### 4.1.PE

# %%
plt.value.table.pe()
# Out:
#        名称     PE  高度(%)  区间    最低值     最高值    中位值  距底(%)    机会值    危险值
# ZXB   中小板  13.62   0.00  极低  13.62   84.11  35.26   0.00  26.72  45.75
# CYB   创业板  25.71  11.57  较低   9.91  147.06  45.78 -61.45  32.17  64.26
# SZB  深市主板  46.53  99.95  极高   9.48   46.53  19.73 -79.63  16.74  25.58
# SZA  深圳A股  17.18   0.28  极低   9.32   68.35  26.68 -45.75  23.03  37.00
# SHA  上海A股  16.75  91.40  极高   9.27   59.05  13.31 -44.66  10.99  15.92
# HSA  沪深A股  28.41  98.59  极高  11.69   54.22  16.03 -58.85  13.44  20.68

# %% [markdown]
# ### 4.2.PB

# %%
plt.value.table.pb()
# Out:
#        名称    PB  高度(%)  区间   最低值    最高值   中位值  距底(%)   机会值   危险值
# ZXB   中小板  2.87  26.56  偏低  1.40   8.67  3.34 -51.22  2.77  4.38
# CYB   创业板  4.30  55.62  合理  1.38  13.05  4.13 -67.91  2.98  5.89
# SZB  深市主板  1.87  18.99  较低  1.42   5.66  2.27 -24.06  1.88  2.85
# SZA  深圳A股  2.66  37.94  偏低  1.69   6.86  2.90 -36.47  2.46  3.72
# SHA  上海A股  1.46  25.29  偏低  1.24   4.94  1.66 -15.07  1.42  1.89
# HSA  沪深A股  1.79  32.68  偏低  1.43   3.95  2.01 -20.11  1.70  2.30

# %% [markdown]
# ### 4.3.股息率

# %%
plt.value.table.dyr()
# Out:
#        名称   股息率  高度(%)  区间   最低值   最高值   中位值  距底(%)   机会值   危险值
# ZXB   中小板  0.98  43.77  合理  0.29  5.28  1.05 -70.41  0.70  1.48
# CYB   创业板  0.50  45.89  合理  0.14  2.86  0.52 -72.00  0.33  0.97
# SZB  深市主板  1.48  60.23  偏高  0.36  6.32  1.22 -75.68  0.95  1.89
# SZA  深圳A股  1.01  38.32  偏低  0.32  5.34  1.08 -68.32  0.79  1.36
# SHA  上海A股  2.11  48.19  合理  0.16  5.95  2.12 -92.42  1.83  2.69
# HSA  沪深A股  1.66  35.35  偏低  0.29  2.91  1.81 -82.53  1.47  2.20

# %% [markdown]
# ## 5.估值图表

# %% [markdown]
# ### 5.1.PE

# %%
plt.value.chart.pe()
# Out:
# ../TL\tl.py:195: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).last()
#   df = df.resample(period,how="last")
# ../PF\pf.py:1062: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_val = table.ix[code, item]
# ../PF\pf.py:1064: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_ratio = table.ix[code, item + '_ratio']
# ../PF\pf.py:1066: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_median = table.ix[code, item + '_median']
# ../PF\pf.py:1067: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_chance = table.ix[code, item + '_q' + str(self.analyse.chance)]
# ../PF\pf.py:1068: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_danger = table.ix[code, item + '_q' + str(self.analyse.danger)]
# ../PF\pf.py:1069: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_min = table.ix[code, item + '_min']
# ../PF\pf.py:1070: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_max = table.ix[code, item + '_max']
# ../PF\pf.py:1071: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_mean = table.ix[code, item + '_mean']

# %% [markdown]
# ### 5.2.PB

# %%
plt.value.chart.pb()

# %% [markdown]
# ### 5.3.股息率

# %%
plt.value.chart.dyr()

# %% [markdown]
# ## 6.行情图表

# %% [markdown]
# ### 6.1.PE

# %%
fig=plt.change.chart.heat(plt.pool.track,'pe',title='板块-PE 阶段涨跌')

# %% [markdown]
# ### 6.2.PB

# %%
fig=plt.change.chart.heat(plt.pool.track,'pb',title='板块-PB 阶段涨跌')

# %% [markdown]
# ## 7.标的

# %% [markdown]
# ### 7.1.创建标的

# %%
_codes={
    'SHA':'上海A股',
    'SZA':'深圳A股',
    'HSA':'沪深A股',
    'SZB':'深市主板',
    'ZXB':'中小板',
    'CYB':'创业板',
   }

plt.pool.create(_codes)

# %% [markdown]
# ### 7.2.显示标的

# %%
plt.pool.show()
# Out:
#        名称
# ZXB   中小板
# CYB   创业板
# SZB  深市主板
# SZA  深圳A股
# SHA  上海A股
# HSA  沪深A股
