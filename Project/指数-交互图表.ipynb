# %% [markdown]
# # 指数交互图表
#
# - 作者：DGC'Idea
# - 版本：V0.1
# - 更新日期：2018年5月4日
#
# ----------

# %%
import pandas as pd 
import numpy as np

from IPython.display import display
from ipywidgets import *


import sys
sys.path.append('../PF')
sys.path.append('../VD')

from pf_idx import Index
from vd_idx import idxView 

index=Index('csv','../Data/')
idxview=idxView(index)
# Out:
# 数据引擎：准备好
# auth success
# 指数框架：运行于研究

# %% [markdown]
# ## 1.更新数据

# %%
from pf_idx import Index
from pf_mcr import Mcr

index=Index('csv','../Data/')
mcr=Mcr('csv','../Data/')

# 指数数据
index.data.update(index.pool.track)
# 10年期国债数据
mcr.data.update(['C10Y'])
# 
#数据分析
index.value.update(index.pool.value,[10,5,3,0],True)
index.change.update(index.pool.track,['close','pe_e','pb_e'],force=True)
# Out:
# Traceback (most recent call last):
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-3-b68f2806cb0a>", line 1, in <module>
#     from pf_idx import Index
#
#   File "../PF\pf_idx.py", line 32, in <module>
#     from pf import *
#
#   File "../PF\pf.py", line 240
#     return df
#     ^
# IndentationError: unexpected unindent

# %% [markdown]
# ## 2.行情

# %%
idxview.change()

# %% [markdown]
# ## 3.分析表

# %%
idxview.table()
# Out:
#                名称     PE  高度(%)  区间    最低值     最高值    中位值  距底(%)    机会值  \
# 000902.SH     全市场  30.39  28.10  偏低  21.70   88.52  35.37 -28.59  28.83
# 399106.SZ    深证综指  36.88  36.94  偏低  24.22  104.69  40.45 -34.33  33.28
# 000001.SH    上证综指  24.18  16.66  较低  18.85   86.27  30.13 -22.04  24.60
# 000985.SH    中证全指  29.63  28.55  偏低  21.27   87.33  32.64 -28.21  28.16
# 399101.SZ    中小板综  36.93  32.58  偏低  24.35  107.43  42.48 -34.06  33.32
# 399102.SZ    创业板综  52.04  49.65  合理  26.89  144.08  52.16 -48.33  38.69
# 000016.SH    上证50  12.14  47.84  合理   9.57   30.52  12.28 -21.17  10.86
# 000010.SH   上证180  15.02  26.29  偏低  12.40   39.42  17.34 -17.44  14.60
# 000300.SH   沪深300  16.91  28.47  偏低  13.41   39.96  19.49 -20.70  16.39
# 000905.SH   中证500  22.21  13.78  较低  16.26   72.42  30.08 -26.79  25.20
# 000852.SH  中证1000  28.45  25.70  偏低  19.69  118.16  47.42 -30.79  26.92
# 399330.SZ   深证100  25.52  63.39  偏高  15.38   46.34  23.50 -39.73  19.63
# 399006.SZ    创业板指  48.38  50.79  合理  24.29  126.18  47.97 -49.79  37.58
# 399005.SZ    中小板指  27.61  29.12  偏低  17.75   70.20  32.17 -35.71  26.10
# 000009.SH   上证380  17.25  10.14  较低  14.41   67.31  25.64 -16.46  21.26
# 000903.SH   中证100  12.63  29.49  偏低   9.81   32.34  13.94 -22.33  12.00
# 000904.SH   中证200  20.35  22.54  偏低  14.71   51.32  24.53 -27.71  20.05
# 000906.SH   中证800  19.88  14.44  较低  15.13   52.50  25.11 -23.89  20.60
# 399001.SZ    深证成指  25.54  64.66  偏高  12.61   75.21  22.06 -50.63  16.78
# 399673.SZ   创业板50  55.39  60.04  偏高  24.51  131.76  51.49 -55.75  40.94
# 000991.SH    全指医药  33.89  25.50  偏低  22.00   88.24  40.87 -35.08  31.92
# 000992.SH    全指金融  12.04  18.76  较低   9.46   28.37  15.07 -21.43  12.21
# 000902.SH   50.49
# 399106.SZ   58.60
# 000001.SH   41.57
# 000985.SH   49.95
# 399101.SZ   59.00
# 399102.SZ   74.08
# 000016.SH   14.68
# 000010.SH   21.32
# 000300.SH   23.23
# 000905.SH   41.12
# 000852.SH   64.31
# 399330.SZ   28.11
# 399006.SZ   62.15
# 399005.SZ   39.60
# 000009.SH   35.60
# 000903.SH   16.68
# 000904.SH   29.14
# 000906.SH   31.80
# 399001.SZ   38.15
# 399673.SZ   70.08
# 000991.SH   48.20
# 000992.SH   17.65
# 000990.SH   47.95
# 000993.SH   69.69
# 000807.SH   44.49
# 000922.SH   17.75
# 399812.SZ   34.64
# 399967.SZ  105.60
# 000827.SH   38.52
# 399971.SZ   53.86
# 000989.SH   41.01
# 000988.SH   47.68
# 000986.SH   60.22
# 000931.SH   30.76
# 000015.SH   14.69
# 000068.SH   54.94
# 000998.SH   51.30
# 000978.SH   39.83
# 399989.SZ   66.75
# 399986.SZ    7.72
# 399814.SZ   38.47
# 399975.SZ   37.96
# 399324.SZ   20.20
# 399976.SZ   54.00
# 399808.SZ   49.69
# 399806.SZ   56.08
# 000925.SH   12.74
# 399550.SZ   18.77
# 000977.SH   36.16
# 000841.SH   37.52
# 399624.SZ   58.11
# 399811.SZ   64.14
# 399396.SZ   41.63
# 000932.SH   42.60
# 399997.SZ   35.97
# HSI         15.01
# HSCEI       11.38
# SPX         23.41

# %% [markdown]
# ## 4.A股指数走势对比

# %%
idxview.line_multi()

# %% [markdown]
# ## 5.A股全市场指数

# %%
idxview.line_qsc()
# Out:
# ../PF\pf_idx.py:398: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_val = table.ix[code1, item]
# ../PF\pf_idx.py:400: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_ratio = table.ix[code1, item + '_ratio']
# ../TL\tl.py:195: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).last()
#   df = df.resample(period,how="last")

# %% [markdown]
# ## 6.A股指数走势

# %%
idxview.line_hs()
# Out:
# ../PF\pf.py:1061: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_val = table.ix[code, item]
# ../PF\pf.py:1063: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_ratio = table.ix[code, item + '_ratio']
# ../PF\pf.py:1065: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_median = table.ix[code, item + '_median']
# ../PF\pf.py:1066: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_chance = table.ix[code, item + '_q' + str(self.analyse.chance)]
# ../PF\pf.py:1067: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_danger = table.ix[code, item + '_q' + str(self.analyse.danger)]
# ../PF\pf.py:1068: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_min = table.ix[code, item + '_min']
# ../PF\pf.py:1069: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_max = table.ix[code, item + '_max']
# ../PF\pf.py:1070: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   item_mean = table.ix[code, item + '_mean']
# HBox(children=(VBox(children=(Select(description='项目', layout=Layout(height='92px'), options={'000902 全市场': '0…
# Output()

# %% [markdown]
# ## 7.A股指数走势自定义对比

# %%
idxview.line_compar()
# Out:
# 至少选择2个、最多8个！
# HBox(children=(VBox(children=(SelectMultiple(description='项目', index=(0,), options={'000902 全市场': '000902.SH',…
# Output()

# %% [markdown]
# ## 8.海外指数走势

# %%
idxview.line_hw()
# Out:
# HBox(children=(VBox(children=(Select(description='项目', layout=Layout(height='92px'), options={'HSI 恒生指数': 'HSI…
# Output()

# %% [markdown]
# # 9.相对强弱
# - 相对强弱值上涨，意味着相应的行业相对标的正在走强。除了可以直接观察比值的走势，也可以借用新高、阻力支撑等传统趋势分析的技术进行分析。

# %%
idxview.line_ratio()
# Out:
# HBox(children=(Select(description='项目', layout=Layout(height='60px', width='240px'), options={'000902 全市场': '0…
# Output()
